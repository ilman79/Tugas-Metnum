# %%
# Fixed Point Iteration Method
# Importing math to use sqrt function
import math

def f(x):
    return x**3 + 4*x**2 -10

# Re-writing f(x)=0 to x = g(x)
def g(x):
    return x - x**3 - 4*x**2 + 10

# Implementing Fixed Point Iteration Method
def fixedPointIteration(x0, e, N):
    print('\n\n*** FIXED POINT ITERATION ***')
    step = 0
    flag = 1
    condition = True
    while condition:
        x1 = g(x0)
        print('Iteration-%d, x0 = %0.9f' % (step, x0))
        x0 = x1

        step = step + 1
        
        if step > N:
            flag=0
            break
        
        condition = abs(x1 - x0) < e

    if flag==1:
        print('\nRequired root is: %0.8f' % x1)
    else:
        print('\nDivergen.')

# Input Section
x0 = input('Enter Guess: ')
e = input('Tolerable Error: ')
N = input('Maximum Step: ')

# Converting x0 and e to float
x0 = float(x0)
e = float(e)

# Converting N to integer
N = int(N)


#Note: You can combine above three section like this
# x0 = float(input('Enter Guess: '))
# e = float(input('Tolerable Error: '))
# N = int(input('Maximum Step: '))

# Starting Newton Raphson Method
fixedPointIteration(x0,e,N)
# Out:
# Enter Guess: 1.5
# Tolerable Error: 5
# Maximum Step: 5
#
#
# *** FIXED POINT ITERATION ***
# Iteration-0, x0 = 1.500000000
# Iteration-1, x0 = -0.875000000
# Iteration-2, x0 = 6.732421875
# Iteration-3, x0 = -469.720012002
# Iteration-4, x0 = 102754555.187385112
# Iteration-5, x0 = -1084933870531746352594944.000000000
#
# Divergen.

# %%
# Fixed Point Iteration Method
# Importing math to use sqrt function
import math

def f(x):
    return x**3 + 4*x**2 -10

# Re-writing f(x)=0 to x = g(x)
def g(x):
    return ((10/x) - (4*x))

# Implementing Fixed Point Iteration Method
def fixedPointIteration(x0, e, N):
    print('\n\n*** FIXED POINT ITERATION ***')
    step = 1
    flag = 1
    condition = True
    while condition:
        x1 = g(x0)**1/2
        print('Iteration-%d, x1 = %0.9f' % (step, x0))
        x0 = x1

        step = step + 1
        
        if step > N:
            flag=0
            break
        
        condition = abs(x1 - x0) < e

    if flag==1:
        print('\nRequired root is: %0.8f' % x1)
    else:
        print('\nDivergen.')

# Input Section
x0 = input('Enter Guess: ')
e = input('Tolerable Error: ')
N = input('Maximum Step: ')

# Converting x0 and e to float
x0 = float(x0)
e = float(e)

# Converting N to integer
N = int(N)


#Note: You can combine above three section like this
# x0 = float(input('Enter Guess: '))
# e = float(input('Tolerable Error: '))
# N = int(input('Maximum Step: '))

# Starting Newton Raphson Method
fixedPointIteration(x0,e,N)
# Out:
# Enter Guess: 1.5
# Tolerable Error: 5
# Maximum Step: 5
#
#
# *** FIXED POINT ITERATION ***
# Iteration-1, x0 = 1.500000000
# Iteration-2, x0 = 0.333333333
# Iteration-3, x0 = 14.333333333
# Iteration-4, x0 = -28.317829457
# Iteration-5, x0 = 56.459091710
#
# Divergen.

# %%
# Fixed Point Iteration Method
# Importing math to use sqrt function
import math

def f(x):
    return x**3 + 4*x**2 -10

# Re-writing f(x)=0 to x = g(x)
def g(x):
    return math.sqrt((10 -x**3)/4)

# Implementing Fixed Point Iteration Method
def fixedPointIteration(x0, e, N):
    print('\n\n*** FIXED POINT ITERATION ***')
    step = 0
    flag = 1
    condition = True
    while condition:
        x1 = g(x0)
        print('Iteration-%d, x1 = %0.9f' % (step, x0))
        x0 = x1

        step = step + 1
        
        if step > N:
            flag=0
            break
        
        condition = abs(x1 - x0) < e

    if flag==1:
        print('\nRequired root is: %0.8f' % x1)
    else:
        print('\nDivergen.')

# Input Section
x0 = input('Enter Guess: ')
e = input('Tolerable Error: ')
N = input('Maximum Step: ')

# Converting x0 and e to float
x0 = float(x0)
e = float(e)

# Converting N to integer
N = int(N)


#Note: You can combine above three section like this
# x0 = float(input('Enter Guess: '))
# e = float(input('Tolerable Error: '))
# N = int(input('Maximum Step: '))

# Starting Newton Raphson Method
fixedPointIteration(x0,e,N)
# Out:
# Enter Guess: 1.5
# Tolerable Error: 5
# Maximum Step: 5
#
#
# *** FIXED POINT ITERATION ***
# Iteration-0, x0 = 1.500000000
# Iteration-1, x0 = 1.286953768
# Iteration-2, x0 = 1.402540804
# Iteration-3, x0 = 1.345458374
# Iteration-4, x0 = 1.375170253
# Iteration-5, x0 = 1.360094193
#
# Divergen.

# %%
# Fixed Point Iteration Method
# Importing math to use sqrt function
import math

def f(x):
    return x**3 + 4*x**2 -10

# Re-writing f(x)=0 to x = g(x)
def g(x):
    return math.sqrt(10/(4+x))

# Implementing Fixed Point Iteration Method
def fixedPointIteration(x0, e, N):
    print('\n\n*** FIXED POINT ITERATION ***')
    step = 0
    flag = 1
    condition = True
    while condition:
        x1 = g(x0)
        x1 = float(x1)
        print('Iteration-%d, x1 = %0.9f' % (step, x0))
        x0 = x1

        step = step + 1
        
        if step > N:
            flag=0
            break
        
        condition = abs(x1 - x0) < e
    if flag==1:
        print('\nRequired root is: %0.9f' % x1)
    else:
        print('\nDivergen.')

# Input Section
x0 = input('Enter Guess: ')
e = input('Tolerable Error: ')
N = input('Maximum Step: ')

# Converting x0 and e to float
x0 = float(x0)
e = float(e)


# Converting N to integer
N = int(N)


#Note: You can combine above three section like this
# x0 = float(input('Enter Guess: '))
# e = float(input('Tolerable Error: '))
# N = int(input('Maximum Step: '))

# Starting Newton Raphson Method
fixedPointIteration(x0,e,N)
# Out:
# Enter Guess: 1.5
# Tolerable Error: 5
# Maximum Step: 5
#
#
# *** FIXED POINT ITERATION ***
# Iteration-0, x1 = 1.500000000
# Iteration-1, x1 = 1.348399725
# Iteration-2, x1 = 1.367376372
# Iteration-3, x1 = 1.364957015
# Iteration-4, x1 = 1.365264748
# Iteration-5, x1 = 1.365225594
#
# Divergen.

# %%
# Fixed Point Iteration Method
# Importing math to use sqrt function
import math

# Re-writing f(x)=0 to x = g(x)
def g(x):
    return (3*x**3 + 8*x**2 - x**3 +4*x**2-10)/(3*x**2 + 8*x)

# Implementing Fixed Point Iteration Method
def fixedPointIteration(x0, e, N):
    print('\n\n*** FIXED POINT ITERATION ***')
    step = 0
    flag = 1
    condition = True
    while condition:
        x1 = g(x0)
        print('Iteration-%d, x1 = %0.9f' % (step, x0))
        x0 = x1

        step = step + 1
        
        if step > N:
            flag=0
            break
        
        condition = abs(x1 - x0) < e

    if flag==1:
        print('\nRequired root is: %0.9f' % x1)
    else:
        print('\nDivergen.')

# Input Section
x0 = input('Enter Guess: ')
e = input('Tolerable Error: ')
N = input('Maximum Step: ')

# Converting x0 and e to float
x0 = float(x0)
e = float(e)

# Converting N to integer
N = int(N)


#Note: You can combine above three section like this
# x0 = float(input('Enter Guess: '))
# e = float(input('Tolerable Error: '))
# N = int(input('Maximum Step: '))

# Starting Newton Raphson Method
fixedPointIteration(x0,e,N)
# Out:
# Enter Guess: 1.5
# Tolerable Error: 5
# Maximum Step: 5
#
#
# *** FIXED POINT ITERATION ***
# Iteration-0, x1 = 1.500000
# Iteration-1, x1 = 1.266667
# Iteration-2, x1 = 0.891030
# Iteration-3, x1 = 0.099058
# Iteration-4, x1 = -12.021246
# Iteration-5, x1 = -5.188105
#
# Divergen.
